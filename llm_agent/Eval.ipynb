# %%
import pandas as pd
import matplotlib.pyplot as plt

import csv

# %%
llm_results_filename = './data/results/partial_results.csv'
df_llm_results = pd.read_csv(llm_results_filename)

manual_results_filename = "./data/results/manual_results.csv"
df_manual_results = pd.read_csv(manual_results_filename)

# %%
df_manual_results.rename(columns={"Unnamed: 0": "pmcid",
                                  "Contains human subjects or samples?": "human_presence",
                                  "Does the study report individual participants or biological samples from individual organisms, excluding cell lines and tissue samples from the same organism?": "multi_samples",
                                  "Contains sex and/or sample quantitative data?": "participant_demographics",
                                  "Are there multiple cohorts, disaggregated data or individual-level data?": "multi_cohorts",
                                  "Sex-specific phenotype": "sex_specific_phenotype"}, inplace=True)

# %%
#df_manual_results = df_manual_results[selected_columns]
df_manual_results
# Out:
#     human_presence  participant_demographics  sex_specific_phenotype  \
# 0             True                      True                   False
# 1             True                      True                   False
# 2             True                      True                   False
# 3             True                      True                    True
# 4             True                      True                   False
# ..             ...                       ...                     ...
# 95            True                      True                   False
# 96            True                     False                   False
# 97            True                      True                    True
# 98            True                      True                   False
# 99           False                     False                   False
#
#     multi_samples  multi_cohorts
# 0            True           True
# 1            True           True
# 2            True           True
# ...

# %%
# Define the correct column order
desired_order = ["human_presence", "participant_demographics", "sex_specific_phenotype", "multi_samples", "multi_cohorts"]

# Reorder the columns
df_manual_results = df_manual_results[desired_order]
df_llm_results = df_llm_results[desired_order]
df_manual_results
# Out:
#     human_presence  participant_demographics  sex_specific_phenotype  \
# 0             True                      True                   False
# 1             True                      True                   False
# 2             True                      True                   False
# 3             True                      True                    True
# 4             True                      True                   False
# ..             ...                       ...                     ...
# 95            True                      True                   False
# 96            True                     False                   False
# 97            True                      True                    True
# 98            True                      True                   False
# 99           False                     False                   False
#
#     multi_samples  multi_cohorts
# 0            True           True
# 1            True           True
# 2            True           True
# ...

# %%
df_llm_results
# Out:
#     human_presence  participant_demographics  sex_specific_phenotype  \
# 0             True                     False                   False
# 1             True                      True                    True
# 2             True                     False                    True
# 3             True                      True                    True
# 4             True                      True                   False
# ..             ...                       ...                     ...
# 94            True                      True                    True
# 95           False                     False                   False
# 96            True                      True                    True
# 97            True                      True                   False
# 98            True                     False                   False
#
#     multi_samples  multi_cohorts
# 0           False          False
# 1            True          False
# 2           False          False
# ...

# %%
import pandas as pd

# Define the columns to compare
selected_columns = [
    "human_presence", 
    "participant_demographics", 
    "sex_specific_phenotype", 
    "multi_samples", 
    "multi_cohorts"
]

# Ensure both DataFrames are aligned
df_manual_results = df_manual_results.sort_index().reset_index(drop=True)
df_llm_results = df_llm_results.sort_index().reset_index(drop=True)

# Perform comparison on selected columns only
df_comparison = df_manual_results[selected_columns] == df_llm_results[selected_columns]

# Convert to Boolean values if needed (ensures proper True/False format)
df_comparison = df_comparison.astype(bool)

# Optionally, add an identifier column if the original DataFrames had more information
df_comparison.insert(0, "index", df_manual_results.index)

# Display the result
print(df_comparison)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_969158/2870330505.py in ?()
#      13 df_manual_results = df_manual_results.sort_index().reset_index(drop=True)
#      14 df_llm_results = df_llm_results.sort_index().reset_index(drop=True)
#      15
#      16 # Perform comparison on selected columns only
# ---> 17 df_comparison = df_manual_results[selected_columns] == df_llm_results[selected_columns]
#      18
#      19 # Convert to Boolean values if needed (ensures proper True/False format)
#      20 df_comparison = df_comparison.astype(bool)
#
# ~/git/pro/bsc/biohackathon-2022-project-24/venv/lib/python3.12/site-packages/pandas/core/ops/common.py in ?(self, other)
#      72                     return NotImplemented
#      73
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#
# ...

# %%
# Define the columns to compare
selected_columns = [
    "human_presence", 
    "participant_demographics", 
    "sex_specific_phenotype", 
    "multi_samples", 
    "multi_cohorts"
]

# Select only relevant columns and ensure column order is the same
df_manual_selected = df_manual_results[selected_columns].copy()
df_llm_selected = df_llm_results[selected_columns].copy()

# Ensure both DataFrames have the same index (reset if needed)
df_manual_selected = df_manual_selected.reset_index(drop=True)
df_llm_selected = df_llm_selected.reset_index(drop=True)

# Now perform the comparison
df_comparison = df_manual_selected == df_llm_selected

# Convert to Boolean values explicitly (optional)
df_comparison = df_comparison.astype(bool)

# Optionally, add an identifier if needed
df_comparison.insert(0, "index", df_manual_results.index)

# Display the result
print(df_comparison)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_413711/1477793647.py in ?()
#      15 df_manual_selected = df_manual_selected.reset_index(drop=True)
#      16 df_llm_selected = df_llm_selected.reset_index(drop=True)
#      17
#      18 # Now perform the comparison
# ---> 19 df_comparison = df_manual_selected == df_llm_selected
#      20
#      21 # Convert to Boolean values explicitly (optional)
#      22 df_comparison = df_comparison.astype(bool)
#
# ~/git/pro/bsc/biohackathon-2022-project-24/venv/lib/python3.12/site-packages/pandas/core/ops/common.py in ?(self, other)
#      72                     return NotImplemented
#      73
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#
# ~/git/pro/bsc/biohackathon-2022-project-24/venv/lib/python3.12/site-packages/pandas/core/arraylike.py in ?(self, other)
# ...

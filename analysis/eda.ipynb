# %%
import sqlite3
import os
import shutil

# %%
import pandas as pd
import matplotlib as mp

# %%
DB_FILE = '../data/db_info_articles_test.sqlite3'

# %%
# Connect to the db
conn = sqlite3.connect(DB_FILE)
sql_query = '''
SELECT * FROM status
'''

# %%
df = pd.read_sql_query(sql_query, conn)

# %%
df['article_type'].value_counts()
# Out:
# research-article       560305
# review-article          31397
# brief-report             6674
# case-report              2711
# other                    2384
# systematic-review        2112
# abstract                 1314
# data-paper               1016
# methods-article           884
# protocol                  643
# letter                    563
# editorial                 370
# report                    365
# chapter-article           347
# product-review            266
# discussion                231
# article-commentary        175
# meeting-report            107
# rapid-communication        58
# news                       27
# calendar                   19
# correction                 19
# in-brief                   13
# book-review                12
# introduction                9
# announcement                7
# addendum                    6
# obituary                    3
# retraction                  2
# reply                       2
# review-article              1
# ...

# %%
df.head()
# Out:
#         pmcid api_response      article_type abstract article_categories  \
# 0  PMC9737133          200  research-article        0                  1
# 1  PMC9683380          200  research-article        0                  1
# 2  PMC6386991          200  research-article        1                  1
# 3  PMC5137654          200  research-article        0                  1
# 4  PMC9609437          200  research-article        1                  1
#
#   article_title authors copyright_info funding publisher_id  ... keywords  \
# 0             1       1              1       0            1  ...        1
# 1             1       1              1       0            0  ...        1
# 2             1       1              1       0            1  ...        1
# 3             1       1              1       0            1  ...        1
# 4             1       1              1       0            1  ...        1
#
#   publication_date INTRO METHODS SUBJECTS RESULTS DISCUSSION CONCLUSION  \
# ...

# %%
#df[df['article_type'] =='research-article'].value_counts().plot(kind='bar', color=['green', 'orange'], edgecolor='grey')

# %%
#df[''].plot(kind='hist', bins=50, color='skyblue', edgecolor='black')
